# %% [markdown]
# # Data Exploration

# %% [markdown]
# Goal: understand grain, coverage, and data-quality gaps. **No conclusions here.**

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
from src.utils.db import read_sql
from src.utils.config_loader import load_config
cfg = load_config()

# %%
df = read_sql('SELECT * FROM marts.mart_daily_volume_by_borough')
df['date_day'] = pd.to_datetime(df['date_day'])
df.head()

# %%
df.groupby('borough')['volume'].describe()

# %% [markdown]
# Checklist: missing boroughs, duplicate keys, category renames over time, channel availability by year.
